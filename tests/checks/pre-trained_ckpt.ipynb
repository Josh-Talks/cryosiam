# %%
import torch

# %%
path = "/g/kreshuk/talks/cryosiam_results/dense_simsiam_pretrained.ckpt"

# %%
with open(path, "rb") as f:
    checkpoint = torch.load(f)
# Out:
# /tmp/ipykernel_3074475/797674739.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f)

# %%
checkpoint.keys()
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
checkpoint['hyper_parameters'].keys()
# Out:
# dict_keys(['config'])

# %%
checkpoint['hyper_parameters']['config']
# Out:
# {'data_folder': '/scratch/stojanov/simulated_datasets/simulated_data/tomograms/without_noise_min_z_inverted_scaled',
#  'mask_folder': None,
#  'validation_ratio': 0.1,
#  'patches_folder': '/g/mahamid/stojanov/simulated_datasets/experiments/dense_simsiam/patches',
#  'log_dir': '/g/zaugg/stojanov/simulated_datasets/experiments/dense_simsiam/version_1',
#  'prediction_folder': '/g/zaugg/stojanov/simulated_datasets/experiments/dense_simsiam/version_1/predictions',
#  'file_extension': '.mrc',
#  'train_files': None,
#  'continue_training': False,
#  'parameters': {'gpu_devices': 8,
#   'nodes': 1,
#   'data': {'patch_size': [128, 128, 128],
#    'view_size': [64, 64, 64],
#    'patch_overlap': 0.5,
#    'view_overlap': 0.5,
#    'min': 0,
#    'max': 1,
#    'mean': 0,
#    'std': 1},
#   'transforms': {'low_pass_sigma_range': [0.5, 2],
#    'high_pass_sigma_range': [0.1, 0.5],
#    'high_pass_sigma2_range': [1, 5],
#    'noise_sigma_range': [0.1, 0.5],
#    'drop_out': 0.5,
# ...

# %%
path = "/g/kreshuk/talks/cryosiam_results/cryosiam_semantic_segmentation.ckpt"
with open(path, "rb") as f:
    checkpoint = torch.load(f)
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
checkpoint.keys()
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
checkpoint['hyper_parameters']['config']
# Out:
# {'data_folder': '/g/zaugg/stojanov/simulated_datasets/final_models/dense_simsiam_regression/version_6/predictions/',
#  'labels_folder': '/g/mahamid/stojanov/simulated_datasets/simulated_data/tomograms/without_noise_inverted_labels',
#  'patches_folder': '/scratch/stojanov/simulated_datasets/final_models/dense_simsiam_semantic/patches_denoised_128',
#  'temp_dir': '/scratch/stojanov/simulated_datasets/final_models/dense_simsiam_semantic',
#  'log_dir': '/g/zaugg/stojanov/simulated_datasets/final_models/dense_simsiam_semantic/version_5',
#  'prediction_folder': '/g/zaugg/stojanov/simulated_datasets/final_models/dense_simsiam_semantic/version_5/predictions',
#  'pretrained_model': '/g/zaugg/stojanov/simulated_datasets/experiments/dense_simsiam/version_1/model/last.ckpt',
#  'file_extension': '.mrc',
#  'train_files': ['sample_1.mrc',
#   'sample_2.mrc',
#   'sample_3.mrc',
#   'sample_4.mrc',
#   'sample_5.mrc',
#   'sample_6.mrc',
#   'sample_7.mrc',
#   'sample_8.mrc',
# ...

# %%
import mrcfile

mrc_file_path = "/scratch/talks/data/cryoetsim_data/combined_clean_inverted_scaled/sample_243_Vol.mrc"
with mrcfile.open(mrc_file_path) as mrc:
    print(mrc.data.shape)
# Out:
# (200, 600, 600)

# %%
with mrcfile.open(mrc_file_path) as mrc:
    print(len(mrc.extended_header)) # If this is > 0, there is extra data.
    print(mrc.header.exttyp) # Tells you the type of extended header.
# Out:
# 0
# b''
